# %% [markdown]
# # **HANDS - ON: FUNDAMENTOS DE LLMS CON MODELOS LLAMA**

# %% [markdown]
# Una vez vista la masterclass ***Fundamentos de LLMs y Arquitectura de Llama***, se proporciona el siguiente ***Colab*** para construir, en vivo, la primera llamada a Llama y medir su comportamiento.
#
# Usamos **Groq** para tener acceso a inferencia de Llama con GPU gratuita, sin necesidad de infraestructura propia.
#
# De igual manera, se proporciona la **solución** de este notebook a través del siguiente [enlace](https://colab.research.google.com/drive/1bjMHw7fmMxo9dyQp140e9mqotKRkfKBg?usp=sharing).

# %% [markdown]
# ## **CONFIGURACIÓN DEL ENTORNO**

# %% [markdown]
# Antes de llamar a Llama necesitamos activar la GPU gratuita de Colab y conectar nuestra cuenta de **Groq**. La librería `groq` es el cliente oficial en Python para hacer llamadas a la API.

# %% [markdown]
# ### **COLAB SECRETS**

# %% [markdown]
# Para no exponer tu ***API key*** directamente en el código, Colab ofrece un panel de ***Secrets*** (ícono de llave en la barra lateral izquierda) donde puedes guardarla de forma segura, añadiendo un nombre asociado a la ***API key*** para guardarla dentro de una variable y usarla dentro del notebook.

# %%
# Instalar cliente de Groq y leer API key desde Colab Secrets
# !pip install groq -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 3.5 MB/s eta 0:00:00

# %%
import os
from groq import Groq
from google.colab import userdata

client = Groq(api_key=userdata.get('APIK'))

# %% [markdown]
# ### **DE PALABRAS A TOKENS**

# %% [markdown]
# Antes de que Llama genere una sola palabra, tu prompt se divide en **tokens**. Vamos a definir un prompt de ejemplo que después enviaremos a Llama.

# %%
# Definir un prompt de ejemplo (una pregunta real de tu propio contexto)
prompt = 'cual es la diferencia entre la RAM y el almacenamiento de una computadora?'
print(prompt)
# Out:
# cual es la diferencia entre la RAM y el almacenamiento de una computadora?

# %% [markdown]
# ### **PRIMERA LLAMADA A LLAMA (ZERO-SHOT)**

# %% [markdown]
# Un LLM predice el siguiente token más probable, **no busca la respuesta en una base de datos**. Vamos a enviar el prompt a Llama en modo zero-shot (sin ejemplos previos) y ver la respuesta generada.

# %%
# Enviar el prompt a Llama en Groq y mostrar la respuesta generada
response = client.chat.completions.create(
    model='llama-3.1-8b-instant',
    messages=[{"role":"user", "content":prompt}]
)

print(response.choices[0].message.content)
# Out:
# La RAM (Memoria Rámbla) y el almacenamiento de una computadora son componentes importantes pero diferentes en una computadora. La principal diferencia entre ambos es la función que cumplen.
#
# **Memoria RAM (RAM):**
#
# La RAM es un componente que almacena temporalmente la información que la computadora está utilizando actualmente. Es como una "mesa de trabajo" donde la computadora puede acceder rápidamente a la información necesaria para realizar tareas. La RAM es necesaria para ejecutar aplicaciones y programas en segundo plano.
#
# **Características de la RAM:**
#
# * Es volátil, lo que significa que el contenido se borra cuando se apaga la computadora.
# * La información se pierde después de apagar la computadora.
# * La RAM es crucial para la velocidad y rendimiento de la computadora.
# * La RAM se refresca continuamente para mantener la información actualizada.
#
# **Almacenamiento de una computadora:**
#
# El almacenamiento de una computadora es un componente que guarda datos de forma permanente, incluso después de apagar la computadora. Es como un "archivador" donde la computadora almacena archivos, programas y datos de larga duración.
#
# **Características del almacenamiento:**
#
# * Es no volátil, lo que significa que el contenido permanece incluso después de apagar la computadora.
# * La información se mantiene después de apagar la computadora.
# * El almacenamiento es necesario para almacenar archivos, programas y datos de larga duración.
# * La velocidad de acceso a los datos del almacenamiento es generalmente lenta en comparación con la RAM.
#
# **Tipos de almacenamiento comunes:**
#
# * SSD (Solid-State Drive): Un tipo de almacenamiento basado en flash que almacena datos de forma no volátil.
# * HDD (Hard Disk Drive): Un tipo de almacenamiento mecánico que almacena datos en un disco giratorio.
# * NVMe (Non-Volatile Memory Express): Un tipo de almacenamiento de estado sólido que ofrece velocidades de acceso rápidas.
#
# En resumen, la RAM es para la información en uso temporal, mientras que el almacenamiento es para la información de larga duración. Ambos componentes son fundamentales para la funcionamiento de una computadora.

# %% [markdown]
# ### **CUÁNTOS TOKENS CONSUMIÓ EL PROMPT**

# %% [markdown]
# La respuesta de la API trae un resumen (`usage`) con el número de tokens de entrada y de salida. Es la forma más directa de responder: ¿cuántos tokens consumió mi prompt?

# %%
from textwrap import indent
# Mostrar cuántos tokens tuvo el prompt y cuántos tuvo la respuesta
print(response.usage.model_dump_json(indent=2))

print("\n Tokens del prompt:",response.usage.prompt_tokens)
print("Tokens de la respuesta:",response.usage.completion_tokens)
print("Tokens totales:",response.usage.total_tokens)
# Out:
# {
#   "completion_tokens": 487,
#   "prompt_tokens": 52,
#   "total_tokens": 539,
#   "completion_time": 0.801005516,
#   "completion_tokens_details": null,
#   "prompt_time": 0.003743353,
#   "prompt_tokens_details": null,
#   "queue_time": 0.055000986,
#   "total_time": 0.804748869
# }
#
#  Tokens del prompt: 52
# Tokens de la respuesta: 487
# Tokens totales: 539

# %% [markdown]
# ### **MIDIENDO LA LATENCIA DE INFERENCIA**

# %% [markdown]
# Elegir el tamaño correcto de modelo es una decisión de ingeniería, no solo de potencia bruta. Vamos a medir cuánto tarda Llama en responder el mismo prompt.

# %%
# Medir el tiempo de respuesta de Llama para el mismo prompt
import time

inicio = time.time()
response_tiempo = client.chat.completions.create(
    model='llama-3.1-8b-instant',
    messages=[{"role":"user", "content":prompt}]
)

duracion = time.time() - inicio
print(f"Tiempo de respuesta: {duracion:.2f} segundos")
# Out:
# Tiempo de respuesta: 0.82 segundos

# %% [markdown]
# ### **COMPARANDO DOS TAMAÑOS DE MODELO**

# %% [markdown]
# Repite la misma llamada usando la versión más grande de Llama disponible en Groq y compara tiempo de respuesta y calidad contra el modelo ligero.

# %%
# Repetir la llamada con un modelo Llama más grande y comparar tiempo y calidad
inicio = time.time()
response_tiempo = client.chat.completions.create(
    model='llama-3.3-70b-versatile',
    messages=[{"role":"user", "content":prompt}]
)

duracion = time.time() - inicio
print(f"Tiempo de respuesta: {duracion:.2f} segundos")
# Out:
# Tiempo de respuesta: 2.04 segundos

# %% [markdown]
# ## **CHALLENGE: COMPARADOR DE MODELOS LLAMA**

# %% [markdown]
# Una vez visto el ***Hands-On: Fundamentos de LLMs***, se presenta el siguiente reto para que el alumnado pueda repasar y reforzar lo aprendido dentro de la clase.

# %% [markdown]
# Se construirá un pequeño **comparador que envíe 3 preguntas** reales a Llama y registre, para cada una, el **tiempo de respuesta** y el **número de tokens** consumidos.

# %% [markdown]
# **IMPORTANTE:** Para su revisión, **es indispensable que los apartados anteriores se encuentren llenados con el código visto durante la sesión.**

# %% [markdown]
# ### **INSTRUCCIONES:**

# %% [markdown]
# **1. Carga la API key y genera 3 preguntas:**
#
#    * Lee la API key de llama ya configurada desde **Colab Secrets**.
#    * Construye una lista vacía llamada `preguntas` y agrégale 3 preguntas frecuentes de tu propio contexto (soporte técnico, tienda, escuela, etc.).

# %%
# Leer API key desde Colab Secrets
import os
import time
from groq import Groq
from google.colab import userdata

client = Groq(api_key=userdata.get('APIK'))

# %%
# Definir la lista de preguntas
preguntas = []
preguntas.append("Que es iso 26262?")
preguntas.append("Explicame que es el FTTI")
preguntas.append("Explicame que es el FSM")

# %% [markdown]
# **2. Consulta la primera pregunta:** Envía la primera pregunta a Llama usando el modelo más ligero disponible en Groq. Guarda la respuesta, el tiempo de respuesta y el número de tokens en un diccionario llamado `resultado_1`.

# %%
# Consultar la primera pregunta y guardar el resultado en resultado_1

inicio1 = time.time()
response1 = client.chat.completions.create(
    model='llama-3.1-8b-instant',
    messages=[{"role":"user", "content":preguntas[0]}]
)

duracion1 = time.time() - inicio1

resultado_1 = {"Respuesta":response1.choices[0].message.content,
               "duracion":duracion1,
               "nTokens":response1.usage.completion_tokens}
# Out:
# 590

# %% [markdown]
# **3. Repite para la segunda y tercera pregunta:** Crea `resultado_2` y `resultado_3` de la misma forma.

# %%
# Consultar la segunda pregunta y guardar el resultado en resultado_2
inicio2 = time.time()
response2 = client.chat.completions.create(
    model='llama-3.1-8b-instant',
    messages=[{"role":"user", "content":preguntas[1]}]
)

duracion2 = time.time() - inicio2

resultado_2 = {"Respuesta":response2.choices[0].message.content,
               "duracion":duracion2,
               "nTokens":response2.usage.completion_tokens}

# %%
# Consultar la tercera pregunta y guardar el resultado en resultado_3
inicio3 = time.time()
response3 = client.chat.completions.create(
    model='llama-3.1-8b-instant',
    messages=[{"role":"user", "content":preguntas[2]}]
)

duracion3 = time.time() - inicio3

resultado_3 = {"Respuesta":response3.choices[0].message.content,
               "duracion":duracion3,
               "nTokens":response3.usage.completion_tokens}

# %% [markdown]
# **4. Junta los resultados:** Agrega `resultado_1`, `resultado_2` y `resultado_3` a una lista vacía llamada `resultados`.

# %%
# Definir la lista resultados y agregar los tres diccionarios
resultados = []
resultados.append(resultado_1)
resultados.append(resultado_2)
resultados.append(resultado_3)

# %% [markdown]
# **5. Muestra la comparación:** Imprime `resultados` y concluye si el modelo ligero resolvió las 3 preguntas satisfactoriamente.

# %%
# Mostrar la tabla final de resultados
print(resultados[0])
print(resultados[1])
print(resultados[2])
# Out:
# {'Respuesta': 'ISO 26262 es un estándar internacional que se enfoca en la seguridad de los sistemas de control, la electrónica y las funciones informáticas en la automatización de vehículos (SAE) que requieren un alto nivel de redundancia, es decir, no se limita a solo automóviles de serie, sino que también incluye buses, camionetas, furgonetas, furgones de entrega y otros vehículos no convencionales.\n\nEste estándar fue desarrollado por la Organización Internacional de Normalización (ISO) en colaboración con la Comisión S-13, que es un comité técnico de la Society of Automotive Engineers (SAE) de Estados Unidos.\n\nEl objetivo principal de ISO 26262 es establecer las normas y requisitos para el diseño, desarrollo y evaluación de los sistemas de seguridad en vehículos, con el fin de garantizar la seguridad de los ocupantes, los peatones y otros usuarios de la carretera.\n\nEl estándar se centra en los aspectos siguientes:\n\n1. **Análisis de fallas y evaluación del riesgo**: se debe identificar y evaluar los riesgos asociados con el sistema de seguridad, para determinar la probabilidad y el impacto de una falla.\n2. **Diseño de seguridad**: se deben implementar medidas para prevenir o reducir los riesgos identificados en el análisis de fallas.\n3. **Verificación y validación**: se deben realizar pruebas y comprobaciones para asegurarse de que el sistema de seguridad funcione correctamente y cumpla con los requisitos establecidos.\n4. **Evaluación de la seguridad**: se debe evaluar la seguridad del sistema de seguridad en diferentes escenarios y condiciones.\n\nEl estándar ISO 26262 se divide en 10 partes, que cubren los siguientes temas:\n\n1. **Concepción y planificación** (ISO 26262-1)\n2. **Análisis de requisitos de seguridad** (ISO 26262-3)\n3. **Análisis de fallas y evaluación del riesgo** (ISO 26262-5)\n4. **Diseño de seguridad** (ISO 26262-6)\n5. **Implantación de software** (ISO 26262-8)\n6. **Verificación y validación** (ISO 26262-9)\n7. **Evaluación de la seguridad** (ISO 26262-10)\n\nEn resumen, ISO 26262 es un estándar internacional que establece las normas y requisitos para la seguridad de los sistemas de control y electrónica en vehículos, con el objetivo de garantizar la seguridad de los ocupantes, los peatones y otros usuarios de la carretera.', 'duracion': 1.9979281425476074, 'nTokens': 590}
# {'Respuesta': 'El FTTI se refiere a la tecnología de fibra óptica "Fiber to the Internet" (fibra a internet). De manera más genérica también puede tratarse del término "fibra a la instalación".\n\nLa "fibra a instalación o FTTI" se refiere a infraestructura de red en la que se instala fibra óptica hasta el punto de acceso donde es necesaria. Esto puede ser hasta una instalación (ya sea un negocio, hogar, etc.), pero no necesariamente es hasta el terminal individual.\n\nPor lo tanto, el "FTTI" se podría considerar un término amplio de "fibra para una instalación", que no necesariamente va directamente a una computadora en particular. Esto se contrapone a "FTTP" o "fibra a punto de usuario" que se refiere a conectar cada dispositivo individual mediante fibra óptica.\n\nEl "FTTI" es una forma más económica de realizar la infraestructura de fibra óptica, pero menos eficiente, ya que requiere una menor inversión inicial, ya que puede compartirse con una cantidad de usuarios dentro de una misma instalación.', 'duracion': 0.760474681854248, 'nTokens': 255}
# {'Respuesta': 'FSM se refiere a "Finite State Machine" (Máquina de Estado Finita en español). Es un modelo conceptual de un sistema automático que puede estar en uno de un número finito de estados. Un estado en este contexto define la situación actual del sistema.\n\nLas FSM están diseñadas para gestionar la secuencia de eventos que ocurren en un sistema. Pueden ser utilizados para modelar y analizar sistemas computacionales, de comunicación, de control, entre otros. \n\nUna FSMA normalmente tiene los siguientes componentes:\n\n1. **Estado actual**: el estado en el que se encuentra el sistema actualmente.\n2. **Estados finales**: los estados finales en los que el sistema quiere o necesita estar. \n3. **Transiciones**: los cambios entre estados.\n4. **Estados iniciales**: el estado en el que el sistema comienza (o inicializa).\n5. **Entradas**: los datos o señales externos que el sistema utiliza para realizar cambios en su estado (transiciones).\n\nLas funciones más comunes de una FSM incluyen:\n\n1. **Autómata finito**: la FSMA solo puede ser en un número finito de estados.\n2. **Recursividad**: el sistema puede reconocer patrones en una secuencia, para luego tomar decisiones sobre lo que hacer a continuación.\n3. **Autómata finito reconocedor**: la FSM tiene en sí misma una secuencia que es la base de los diferentes patrones.\n4. **Autómata conmemorativo**: la FSM tiene una secuencia reconocible pero es capaz de recordar los pasos anteriores y dar una indicación de su estado actual.\n\nLos FSM se aplican en un amplio rango de áreas, incluyendo:\n\n1. **Autómata**: los reconocimientos automáticos en sistemas.\n2. **Lenguaje de programación**: se utilizan tanto en el procesamiento del texto como para la programación.\n3. **Diseño de redes**: son fundamentales en la configuración de comunicaciones.\n4. **Robotica**: en el control de los movimientos de los robots.', 'duracion': 2.074671506881714, 'nTokens': 453}
